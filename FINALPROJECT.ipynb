# %%
class Hotel:
    
    def __init__(self, name):
        self.hotl_name=name
        self.food={}
        self.food_ID=len(self.food)+1
        self.admin_details={}
        self.user_details={}
        self.ordered_item=[]

        
    # admin functionalities
    
    
    def admin_register(self):
        try:
            self.admin_email=input("Enter your email id : ")
            self.admin_pass=input("Enter your password : ")
            self.admin_details={"Email_ID":self.admin_email,"Password":self.admin_pass}
            print("\n!! Admin Account is  Successfully  Created  !!\n")
            print(f"WELCOME TO {self.restro_name} HOTEL\n")
            print("Admin Details : ")
            for i in self.admin_details:
                print(i, ":", self.admin_details[i])
        except Exception as e:
            print("\n!! Kindly Provide Valid Inputs !!\n ")
            
            
    def admin_login(self):
        try:
            print(f"*****Welcome TO {self.hotl_name} HOTEL*****\n\n")
            email=input("Enter Your mail ID : ")
            pas=input("Enter Your Password : ")
            if len(self.admin_details.values())!=0:
                if email==self.admin_email and pas==self.admin_pass:
                    print("\n!! Login successfull !!")
                    while True:
                        print("\nEnter the Options\n")
                        print("1. Add Food Item \n2. Edit Food Item\n3. View Food Item\n4. Delete Food Item\n5. Exit")
                        a=input()
                        if a=="1":
                            self.add_food_item()
                        elif a=="2":
                            self.edit_food_item()
                        elif a=="3":
                            self.view_food_item()
                        elif a=="4":
                            self.delete_food_item()
                        elif a=="5":
                            break
                        else:
                            print("invalid Number")
                else:
                    print("\n!! Incorrect Email or Password!!\n")
            else:
                print("\n! There is no Admin Account with this Email ID !\n\n!! Kindly Create Your Account !!\n")
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!")
            
        
    def add_food_item(self):
        try:
            name=input("Enter the food name : ")
            quantity=float(input("Enter the quantity in values only : "))
            price=float(input("Enter the price in Rs only : "))
            discount=float(input("Enter the discount in Rs only : "))
            stock=float(input("Enter the available stock in values only : "))
            food_item={"Name":name,"Quantity":quantity,"Price":price,"Discount":discount,"Stock":stock}
            self.food_ID=len(self.food)+1
            self.food[self.food_ID]=food_item
            print("\n!! Food Item added successfully !!\n")
            print("Newly Added items :", self.food,"\n")
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!\n")
        
        
    def edit_food_item(self):
        try:
            b=int(input("Enter the Food ID you want to update : \n"))
            if b in self.food.keys():
                print("1. Update Food Name\n2. Update Quantity\n3. Update Price\n4. Update Discount\n5. Update Stock \n")
                c= input("Enter the number only : ")
                if c=="1":
                    self.food[b]["Name"]=input("Updated Food name : ")
                    print("\n!! Successfully Updated !!\n")
                elif c=="2":
                    self.food[b]["Quantity"]=float(input("Updated Quantity in values only : "))
                    print("\n!! Successfully Updated !!\n")
                elif c=="3":
                    self.food[b]["Price"]=float(input("Updated Price in Rs only : "))
                    print("\n!! Successfully Updated !!\n")
                elif c=="4":
                    self.food[b]["Discount"]=float(input("Updated Discount in Rs only : "))
                    print("\n!! successfully Updated !!\n")
                elif c=="5":
                    self.food[b]["Stock"]=float(input("Updated Stock in values only : "))
                    print("\n!! Successfully Updated !!\n")
                else:
                    print("!! Sorry Invalid Number !!\n")
            else:
                print("\n!! Incorrect Food ID !!\n")
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!\n")  
            
            
    def view_food_item(self):
        print("List of Food Items : \n")
        if len(self.food)!=0:    
            for i in self.food:
                print(f"Food Id : {i}")
                for j in self.food[i]:
                    print(j, ":", self.food[i][j])
                print()
        else:
            print("!! Sorry No Food Items is Added !!\n")
            

    def delete_food_item(self):
        try:
            print("!! Oh Oh Warning !!\nFood Item will be Deleted\n")
            print("Enter the Food ID ")
            b=int(input())
            if b in self.food.keys():
                del self.food[b]
                print("\n!! Food item deleted successfully !!\n")
                print("Updated Food List\n",self.food)
            else:
                print("!! Incorrect Food ID!!\n")
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!\n")
                
                
    # user functionalities
                   
        
    def user_register(self):
        try:
            user_name=input("Enter your full name : ")
            phone_no=int(input("Enter your 10 digit phone number : "))
            email=input("Enter your email id : ")
            password=input("Enter your password : ")
            address=input("Enter your address with area PIN code ")
            self.user_details={"User Name":user_name,"Phone No.":phone_no,"Email_ID":email,"Password":password,"Address":address}
            print("\n!! Your Account is Created Successfully !!\n")
            print(f"*****Welcome TO {self.hotl_name} HOTEL****\n")
            print("User Details : ")
            for i in self.user_details:
                print(i, ":", self.user_details[i])        
        except Exception as e:
            print("\n!!Kindly Provide Valid Inputs !!\n ")      
            
               
    def user_login(self):
        try:
            print(f"******Welcome TO {self.hotl_name} HOTEL\n\n")
            email=input("Enter Your Email ID : ")
            pas=input("Enter Your Password : ")
            if len(self.user_details.values())!=0:                                                            #we can same as admin by using self.email..etc
                if email==self.user_details["Email_ID"] and pas==self.user_details["Password"]:      # we can make it either object level or local level inside def fun
                    print("\n!! Login successfull !!")
                    while True:
                        print("\nEnter the Options\n")
                        print("1. Place New Order\n2. Check Order History\n3. Update Your Profile Details\n4. Exit")
                        a=input()
                        if a=="1":
                            self.place_order()
                        elif a=="2":
                            self.ordered_history()
                        elif a=="3":
                            self.update_details()
                        elif a=="4":
                            break
                        else:
                            print("invalid Number")
                else:
                    print("\n!! Incorrect Email or Password!!\n")
            else:
                print("\n! There is no User Account with this Email ID !\n\n!! Please Create Your Account!!\n")
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!")  
            
            
    def place_order(self):
        try:
            if len(self.food)!=0:
                print("List of Availabe Food Items :\n")
                menu=[]
                for items in self.food:
                    menu.append([self.food[items]["Name"], self.food[items]["Quantity"],self.food[items]["Price"]]) 
                for i in range(len(menu)):
                    print(i+1,".",menu[i])
                while True:
                    print("\nEnter 1 to Place the Order\nEnter 2 to Exit ")
                    b=input()
                    if b=="1":
                        print("Enter the Food number You want to ordered separated by comma")
                        c=input().split(",")
                        for i in y:
                            c=int(i)
                            if c<=len(menu):
                                self.ordered_item.append(menu[z-1])
                            else:
                                print("\nWe Don't have this Food Item : ",z)
                        print("\nList of food item you selected : \n")
                        for j in self.ordered_item:
                            print(j)
                    elif c=="2":
                        break
                    else:
                        print("!! Invalid Number !!\n")
            else:
                print("\n!! Sorry! No Food Items are available Now !!\n")
                        
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!")     
                
                
    def ordered_history(self):
        print("\nList of Previous ordered : \n")
        for i in self.ordered_item:
            print(i)
            
            
    def update_details(self):
        try:
            while True:
                print("Select Below Options to Update Your Profile Details\n")
                print("1. Name\n2. Phone number\n3. Email ID\n4. Password\n5. Address\n6. Exit\n")
                b=input()
                if b=="1":
                    self.user_details["User Name"]=input("Enter your updated full name : ")
                    print("\n!! Detail Updated Successfully !!\n")
                elif b=="2":
                    self.user_details["Phone No."]=int(input("Enter your updated 10 digit phone number : "))
                    print("\n!! Detail Updated Successfully !!\n")      
                elif b=="3":
                    self.user_details["Email_ID"]=input("Enter your updated email id : ")
                    print("\n!! Detail Updated Successfully !!")
                    
                elif b=="4":
                    self.user_details["Password"]=input("Enter your updated password : ")
                    print("\n!! Detail Updated Successfully !!\n")
                    
                elif b=="5":
                    self.user_details["Address"]=input("Enter your updated address with area PIN code ")
                    print("\n!! Detail Updated Successfully !!\n")
                    
                elif b=="6":
                    break
                else:
                    print("\n!! Invalid Number Entered !!\n")
                    
                if b in ["1","2","3",'4',"5"]:
                    for i in self.user_details:
                        print(i, ":",self.user_details[i])
                else:
                    print("\nPlease Enter correct Input\n")      
        except Exception as e:
            print("\n!! Please Provide Valid Inputs !!\n ")
            
            
       # defining the Main function    

try:
    def main():
        obj=Hotel("DAVID AND SON'S ")
        print(f"!! ****** Welcome To {obj.hotl_name} HOTEL******  !!\n")
        print("!!----------------------------------------------------------")
        print("!!----------------------------------------------------------")
        while True:
            print("1. Admin LOGIN \n2. User LOGIN \n3. Exit\n")
            b=input()
            if b=="1":
                while True:
                    print("\nEnter the Below Options\n")
                    print("1. Register\n2. Login\n3. Exit\n")
                    c=input()
                    if c=="1":
                        obj.admin_register()
                    elif c=="2":
                        obj.admin_login()           
                    elif c=="3":
                        break
                    else:
                        print("\nInvalid Number ")
                    
            elif b=="2":
                while True:
                    print("\nEnter the Below Options\n")
                    print("1. ADD \n2. Login\n3. Exit\n")
                    c=input()
                    if c=="1":
                        obj.user_register()
                    elif c=="2":
                        obj.user_login()           
                    elif c=="3":
                        break
                    else:
                        print("\nInvalid Number ")        
            elif b=="3":
                break
            else:
                print("Invalid Number")
except Exception as e:
    print("Something went wrong kindly give correct input")
            
        
        # calling the main function 
        
if __name__=='__main__':
    print("!!!hurrrayyyy!!!!")
main()
# Out:
# !!!hurrrayyyy!!!!
# !! ****** Welcome To DAVID AND SON'S  HOTEL******  !!
#
# !!----------------------------------------------------------
# !!----------------------------------------------------------
# 1. Admin LOGIN
# 2. User LOGIN
# 3. Exit
#
# 1
#
# Enter the Below Options
#
# 1. Register
# 2. Login
# 3. Exit
#
# 1
# Enter your email id : shivu@gmail.com
# Enter your password : pass
#
# !! Admin Account is  Successfully  Created  !!
#
#
# !! Kindly Provide Valid Inputs !!
#
#
# Enter the Below Options
#
# 1. Register
# 2. Login
# 3. Exit
#
# 2
# *****Welcome TO DAVID AND SON'S  HOTEL*****
#
#
# Enter Your mail ID : shivu@gmail.com
# Enter Your Password : pass
#
# !! Login successfull !!
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 1
# Enter the food name : burger
# Enter the quantity in values only : 3
# Enter the price in Rs only : 240
# Enter the discount in Rs only : 30
# Enter the available stock in values only : 7
#
# !! Food Item added successfully !!
#
# Newly Added items : {1: {'Name': 'burger', 'Quantity': 3.0, 'Price': 240.0, 'Discount': 30.0, 'Stock': 7.0}}
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 3
# List of Food Items :
#
# Food Id : 1
# Name : burger
# Quantity : 3.0
# Price : 240.0
# Discount : 30.0
# Stock : 7.0
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 2
# Enter the Food ID you want to update :
# 1
# 1. Update Food Name
# 2. Update Quantity
# 3. Update Price
# 4. Update Discount
# 5. Update Stock
#
# Enter the number only : 4
# Updated Discount in Rs only : 20
#
# !! successfully Updated !!
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 3
# List of Food Items :
#
# Food Id : 1
# Name : burger
# Quantity : 3.0
# Price : 240.0
# Discount : 20.0
# Stock : 7.0
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 4
# !! Oh Oh Warning !!
# Food Item will be Deleted
#
# Enter the Food ID
# 1
#
# !! Food item deleted successfully !!
#
# Updated Food List
#  {}
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 3
# List of Food Items :
#
# !! Sorry No Food Items is Added !!
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 3
# List of Food Items :
#
# !! Sorry No Food Items is Added !!
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 4
# !! Oh Oh Warning !!
# Food Item will be Deleted
#
# Enter the Food ID
# 4
# !! Incorrect Food ID!!
#
#
# Enter the Options
#
# 1. Add Food Item
# 2. Edit Food Item
# 3. View Food Item
# 4. Delete Food Item
# 5. Exit
# 5
#
# Enter the Below Options
#
# 1. Register
# 2. Login
# 3. Exit
#
# 3
# 1. Admin LOGIN
# 2. User LOGIN
# 3. Exit
